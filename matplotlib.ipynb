# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
a1=[1,2,3,4,5]
a2=[6,7,8,9,10]

# %%
plt.plot(a1)
plt.plot(a1,"--")
plt.plot(a1,"*",color="black")
plt.plot(a1,"*--",color="black")
plt.show()

# %%
plt.plot(a1,"r+")
plt.show()

# %%
salary=[15000,25000,20000,100000]
name=["a","b","c","d"]

# %%
plt.plot(name,salary,"*--",color="black")
plt.xlabel("Names")
plt.ylabel("Salary")
plt.title("Emp slalary graph")
plt.show()
